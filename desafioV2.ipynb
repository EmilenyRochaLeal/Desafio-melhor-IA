# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilenyRochaLeal/Desafio-melhor-IA/blob/main/desafioV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y aisuite simple-parsing docstring-parser
# !pip install aisuite[all]
# !pip install docstring-parser
# Out:
# Collecting docstring-parser
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Installing collected packages: docstring-parser
# Successfully installed docstring-parser-0.16

# %%
import os
from getpass import getpass

os.environ['GROQ_API_KEY'] = getpass('Qual sua API key GROQ?')
os.environ['ANTHROPIC_API_KEY'] = getpass('Qual sua API key ANTHROPIC?')
# Out:
# Qual sua API key GROQ?··········
# Qual sua API key ANTHROPIC?··········

# %%
import aisuite as ai
from typing import List
from typing import Dict

client = ai.Client()

def aks(message: str, model: str, system_message: str = "Você é um assistente inteligente que responde em português.") -> str:
    """
    Envia uma mensagem para um modelo de IA e retorna a resposta.
    """
    client = ai.Client()
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": message},
    ]

    response = client.chat.completions.create(model=model, messages=messages)
    return response.choices[0].message.content


def answer(questions: List[str], models: List[str]) -> List[List[str]]:
    """
    Obtém respostas de diferentes modelos de IA para cada pergunta e retorna uma lista de listas com as respostas.
    """
    all_responses = []

    for q_index, question in enumerate(questions):
        print(f"\n##### Pergunta {q_index + 1}: {question} #####\n")
        responses = []
        for m_index, model in enumerate(models):
            print(f'::::: Modelo {m_index + 1}: {model} :::::')
            response = aks(question, model)
            print(response)
            responses.append(response)
            print('--------------\n')
        all_responses.append(responses)

    return all_responses

def auto_comparison(question: str, responses: List[str], model: str) -> str:
    """
    Envia as respostas obtidas para o próprio modelo de IA avaliá-las e ranqueá-las com base em critérios definidos.
    """
    # Criando o prompt de avaliação
    respostas_formatadas = "\n".join([f"{i + 1}) {resposta}" for i, resposta in enumerate(responses)])

    prompt_avaliacao = f"""
    Considere a seguinte pergunta: "{question}"

    Aqui estão as respostas fornecidas por diferentes modelos:
    {respostas_formatadas}

    Por favor, ranqueie essas respostas com base nos seguintes critérios:
    - Clareza e Coerência
    - Precisão da Informação
    - Criatividade ou Profundidade
    - Consistência Gramatical

    Dê qual a melhor resposta.
    """

    # Enviando o prompt para o modelo
    avaliacao = aks(prompt_avaliacao, model)
    return avaliacao

# %%
def main():
    models = [
        'groq:deepseek-r1-distill-llama-70b',
        'anthropic:claude-3-5-sonnet-20241022',
        'groq:llama-3.3-70b-versatile',
    ]

    questions = [
        'O que é Engenharia de software aplicada?',
        'O que é uma função em programação?',
        'Quais os tipos de inteligência artificial?',
        'Como o cérebro realmente aprende?',
        'Porque Oeiras deixou de ser a capital do Piauí?',
    ]

    # Obter respostas
    all_responses = answer(questions, models)

    # 📝 Autoavaliação assistida por IA
    for q_index, question in enumerate(questions):
        print(f"\n📝 Autoavaliação para a pergunta: {question}")
        for model in models:
            print(f"\n🤖 Avaliação do modelo {model}:")
            resultado_avaliacao = auto_comparison(question, all_responses[q_index], model)
            print(f"📊 Resultado da avaliação:\n{resultado_avaliacao}")
            print("====================================================")


if __name__ == "__main__":
    main()
# Out:
# ##### Pergunta 1: O que é Engenharia de software aplicada? #####
#
# ::::: Modelo 1: groq:deepseek-r1-distill-llama-70b :::::
# **Applied Software Engineering: A Comprehensive Overview**
#
# Applied Software Engineering is a practical field that focuses on the application of software engineering principles to develop, maintain, and improve software systems. It emphasizes real-world applications, addressing specific needs and problems through the creation of effective solutions. Here's a structured breakdown:
#
# 1. **Definition and Scope**:
#    - Applied Software Engineering involves the practical application of software engineering principles, distinguishing it from more theoretical aspects. It covers the entire software development lifecycle, including design, development, testing, and maintenance.
#
# 2. **Tools and Methodologies**:
#    - Utilizes various tools such as version control systems and programming languages.
#    - Employs methodologies like Agile, Scrum, and Waterfall to structure and manage projects effectively.
#
# 3. **Problem-Solving Focus**:
#    - Aims to create solutions that address specific issues or enhance existing processes, ensuring software is both functional and efficient.
#
# 4. **Applications Across Industries**:
#    - Versatile in application, spanning web, mobile, systems, and embedded systems development. Examples include mobile apps, e-commerce platforms, and IoT devices.
#
# 5. **Quality and Best Practices**:
#    - Emphasizes the importance of quality, reliability, and efficiency, adhering to best practices and standards to ensure robust software.
#
# 6. **Continuous Learning**:
#    - Requires ongoing education to keep pace with rapidly evolving technologies, tools, and methodologies.
#
# 7. **Collaboration and Integration**:
#    - Involves teamwork with various roles such as project managers and designers, integrating with other disciplines for comprehensive solutions.
#
# In essence, Applied Software Engineering is a dynamic, hands-on field that combines technical skills with problem-solving to deliver practical software solutions across diverse industries.
# --------------
#
# ::::: Modelo 2: anthropic:claude-3-5-sonnet-20241022 :::::
# A Engenharia de Software Aplicada é a disciplina que se concentra na aplicação prática dos princípios, métodos e ferramentas da engenharia de software para desenvolver, manter e gerenciar sistemas de software de forma sistemática e organizada. Eis os principais aspectos:
#
# 1. Principais características:
# - Foco em soluções práticas
# - Uso de metodologias e processos
# - Aplicação de boas práticas
# - Gestão de projetos de software
#
# 2. Áreas de atuação:
# - Desenvolvimento de sistemas
# - Manutenção de software
# - Testes e qualidade
# - Gerenciamento de projetos
# - Análise de requisitos
#
# 3. Benefícios:
# - Maior qualidade do software
# - Redução de custos
# - Melhor controle de prazos
# - Maior satisfação do cliente
# - Maior produtividade
#
# 4. Práticas comuns:
# - Metodologias ágeis
# - Desenvolvimento iterativo
# - Gestão de configuração
# - Documentação
# - Testes automatizados
#
# 5. Ferramentas:
# - IDEs
# - Sistemas de controle de versão
# - Ferramentas de gestão de projetos
# - Frameworks de desenvolvimento
# - Ferramentas de teste
#
# A Engenharia de Software Aplicada é fundamental para o desenvolvimento profissional de software em organizações modernas.
# --------------
#
# ::::: Modelo 3: groq:llama-3.3-70b-versatile :::::
# **Introdução à Engenharia de Software Aplicada**
#
# A Engenharia de Software Aplicada é uma disciplina que combina técnicas de engenharia de software com a aplicação prática em projetos de desenvolvimento de software. Ela envolve a aplicação de princípios, métodos e ferramentas para projetar, desenvolver, testar e manter sistemas de software de alta qualidade.
#
# **Objetivos da Engenharia de Software Aplicada**
#
# Os principais objetivos da Engenharia de Software Aplicada incluem:
#
# 1. **Desenvolver sistemas de software confiáveis e eficientes**: criar sistemas que atendam às necessidades dos usuários e sejam capazes de funcionar corretamente em diferentes ambientes e condições.
# 2. **Melhorar a produtividade e a eficiência**: utilizar técnicas e ferramentas para reduzir o tempo e o custo de desenvolvimento, além de melhorar a qualidade do software.
# 3. **Garantir a manutenção e a evolução do software**: criar sistemas que sejam fáceis de manter e atualizar, permitindo que os desenvolvedores façam alterações e melhorias sem afetar a estabilidade do sistema.
#
# **Áreas de Aplicação da Engenharia de Software Aplicada**
#
# A Engenharia de Software Aplicada pode ser aplicada em diversas áreas, incluindo:
#
# 1. **Desenvolvimento de aplicativos**: criação de aplicativos para desktop, mobile e web.
# 2. **Sistemas de informação**: desenvolvimento de sistemas de informação para empresas e organizações.
# 3. **Sistemas embutidos**: criação de sistemas de software para dispositivos embutidos, como robôs e dispositivos de automação industrial.
# 4. **Sistemas de jogos**: desenvolvimento de jogos para diferentes plataformas.
#
# **Técnicas e Ferramentas Utilizadas**
#
# Algumas das técnicas e ferramentas comuns utilizadas na Engenharia de Software Aplicada incluem:
#
# 1. **Metodologias ágeis**: como Scrum e Kanban.
# 2. **Ferramentas de desenvolvimento**: como IDEs (Ambientes de Desenvolvimento Integrado) e editores de código.
# 3. **Sistemas de controle de versão**: como Git e SVN.
# 4. **Ferramentas de teste e depuração**: como JUnit e Apache JMeter.
#
# **Conclusão**
#
# A Engenharia de Software Aplicada é uma disciplina importante que combina técnicas de engenharia de software com a aplicação prática em projetos de desenvolvimento de software. Ela envolve a aplicação de princípios, métodos e ferramentas para criar sistemas de software de alta qualidade, confiáveis e eficientes. Com a aplicação das técnicas e ferramentas certas, os desenvolvedores podem criar sistemas de software que atendam às necessidades dos usuários e sejam fáceis de manter e atualizar.
# --------------
#
#
# ##### Pergunta 2: O que é uma função em programação? #####
#
# ::::: Modelo 1: groq:deepseek-r1-distill-llama-70b :::::
# Uma função em programação é um bloco de código que executa uma tarefa específica e pode ser chamado várias vezes em diferentes partes do programa. As funções ajudam a organizar o código, tornando-o mais modular, reutilizável e fácil de manter.
#
# ### Principais características de uma função:
# 1. **Nome da Função**: Um identificador que define a ação que a função realiza.
# 2. **Parâmetros**: Valores que podem ser passados para a função quando ela é chamada, permitindo que ela opere com diferentes dados.
# 3. **Corpo da Função**: O conjunto de instruções que são executadas quando a função é chamada.
# 4. **Retorno (opcional)**: A função pode retornar um valor para o local de onde foi chamada.
#
# ### Vantagens do uso de funções:
# - **Reutilização de Código**: Evita a repetição de código, tornando o programa mais eficiente.
# - **Modularidade**: Facilita a organização e a manutenção do código.
# - **Abstração**: Permite que o programador se concentre em "o que" a função faz, em vez de "como" ela faz.
#
# ### Exemplo em Python:
# ```python
# def saudacao(nome):
#     print(f"Olá, {nome}!")
#
# # Chamando a função
# saudacao("João")  # Saída: Olá, João!
# ```
#
# Neste exemplo, `saudacao` é uma função que recebe um parâmetro `nome` e imprime uma saudação personalizada.
# --------------
#
# ::::: Modelo 2: anthropic:claude-3-5-sonnet-20241022 :::::
# Uma função em programação é um bloco de código organizado e reutilizável que executa uma tarefa específica. Pense nela como uma "mini-programa" dentro do seu programa principal. Veja os principais aspectos de uma função:
#
# Características principais:
# 1. Recebe dados (parâmetros/argumentos)
# 2. Processa esses dados
# 3. Retorna um resultado (opcional)
#
# Benefícios:
# - Reutilização de código
# - Melhor organização do programa
# - Facilita a manutenção
# - Torna o código mais legível
#
# Exemplo simples em Python:
# ```python
# def soma(a, b):
#     resultado = a + b
#     return resultado
# ```
#
# Neste exemplo:
# - 'soma' é o nome da função
# - 'a' e 'b' são parâmetros
# - A função retorna a soma dos dois números
#
# É como uma receita de bolo: você fornece os ingredientes (parâmetros), segue um processo (código dentro da função) e obtém um resultado final (valor retornado).
# --------------
#
# ::::: Modelo 3: groq:llama-3.3-70b-versatile :::::
# **Funções em Programação**
#
# Uma função em programação é um bloco de código que realiza uma tarefa específica e pode ser chamada várias vezes em diferentes partes do programa. Ela é como uma caixa onde você coloca um conjunto de instruções que devem ser executadas juntas.
#
# **Características das Funções**
#
# Aqui estão algumas das principais características das funções:
#
# * **Reutilização de código**: As funções permitem que você reutilize código em diferentes partes do programa, evitando a duplicação de código.
# * **Modularidade**: As funções ajudam a dividir o programa em módulos menores e mais fáceis de gerenciar.
# * **Abstração**: As funções podem esconder detalhes de implementação, tornando o código mais fácil de entender e usar.
# * **Reutilização**: As funções podem ser chamadas várias vezes, com diferentes parâmetros, para realizar tarefas diferentes.
#
# **Estrutura de uma Função**
#
# Uma função típica tem a seguinte estrutura:
#
# 1. **Nome da função**: Um nome que identifica a função.
# 2. **Parâmetros**: Valores que são passados para a função quando ela é chamada.
# 3. **Corpo da função**: O bloco de código que é executado quando a função é chamada.
# 4. **Retorno**: O valor que a função retorna após ser executada.
#
# **Exemplo**
#
# Aqui está um exemplo de uma função em Python que calcula a área de um retângulo:
# ```python
# def calcular_area(largura, altura):
#   return largura * altura
#
# area = calcular_area(10, 20)
# print(area)  # Saída: 200
# ```
# Neste exemplo, a função `calcular_area` tem dois parâmetros (`largura` e `altura`) e retorna o valor da área do retângulo.
#
# **Conclusão**
#
# As funções são uma ferramenta poderosa em programação, permitindo que você reutilize código, divida o programa em módulos menores e mais fáceis de gerenciar, e abstraia detalhes de implementação. Compreender como as funções funcionam é fundamental para se tornar um programador eficaz.
# --------------
#
#
# ##### Pergunta 3: Quais os tipos de inteligência artificial? #####
#
# ::::: Modelo 1: groq:deepseek-r1-distill-llama-70b :::::
# A Inteligência Artificial (IA) pode ser classificada de várias maneiras, dependendo do critério utilizado. Abaixo estão algumas das principais categorizações:
#
# ---
#
# ### **1. Baseado na Inteligência Humana**
# - **IA Fraca (Narrow AI):**
#   - Tipo de IA projetada para realizar tarefas específicas, como reconhecimento de voz, jogos de xadrez ou tradução de idiomas.
#   - Exemplos: Chatbots, sistemas de recomendação, assistentes virtuais (como Siri, Alexa).
#
# - **IA Geral (General AI ou Strong AI):**
#   - Tipo de IA que possui inteligência equivalente à humana, capaz de aprender, raciocinar e resolver problemas em qualquer domínio.
#   - Até o momento, a IA geral ainda não foi alcançada e é considerada um objetivo teórico.
#
# - **IA Superinteligente:**
#   - Tipo de IA que supera em muito a inteligência humana em todos os aspectos, tornando-se capaz de resolver problemas complexos de forma autônoma.
#   - Ainda está no âmbito da especulação e do debate ético.
#
# ---
#
# ### **2. Baseado no Pensamento**
# - **IA Reativa:**
#   - Responde a entradas imediatas sem manter memória ou aprender com as interações.
#   - Exemplo: O IBM Deep Blue, que joga xadrez sem aprender com as partidas anteriores.
#
# - **IA Limitada no Tempo (Limited Memory):**
#   - Combina IA reativa com a capacidade de "lembrar" algumas informações por um curto período.
#   - Exemplo: Veículos autônomos que usam dados recentes para tomar decisões.
#
# - **IA Forte (Strong AI):**
#   - Possui consciência, autoconsciência e entendimento humano.
#   - Ainda não foi alcançada.
#
# - **IA Superinteligente:**
#   - Como mencionado anteriormente, supera a inteligência humana em todos os aspectos.
#
# ---
#
# ### **3. Baseado na Autonomia**
# - **IA Controlada:**
#   - Funciona sob um conjunto rígido de regras e não tem autonomia para tomar decisões por conta própria.
#   - Exemplo: Sistemas de automação industrial.
#
# - **IA Autônoma:**
#   - Possui algum grau de autonomia para tomar decisões, mas ainda está limitada a um conjunto definido de tarefas.
#   - Exemplo: Drones autônomos que seguem rotas pré-programadas.
#
# - **IA Social:**
#   - Capaz de interagir com humanos de forma natural, entendendo emoções e contextos sociais.
#   - Exemplo: Robôs sociais como o Sophia.
#
# ---
#
# ### **4. Baseado no Aprendizado**
# - **IA Supervisionada:**
#   - Aprendizagem baseada em dados rotulados, onde o sistema é treinado com entradas e saídas esperadas.
#   - Exemplo: Sistemas de classificação de imagens.
#
# - **IA Não Supervisionada:**
#   - Aprendizagem baseada em dados não rotulados, onde o sistema procura padrões ou estruturas nos dados.
#   - Exemplo: Análise de clusters para segmentação de mercados.
#
# - **IA por Reforço:**
#   - Aprendizagem por meio de tentativas e erros, onde o sistema recebe recompensas ou penalidades para otimizar seu comportamento.
#   - Exemplo: Agentes de jogos que aprendem a tomar decisões ótimas.
#
# ---
#
# ### **5. Baseado em Aplicação**
# - **IA em Processamento de Linguagem Natural (NLP):**
#   - Trabalha com texto e linguagem humana, como tradução, resumo de textos ou geração de conteúdo.
#   - Exemplo: Chatbots e tradutores automáticos.
#
# - **IA em Visão Computacional:**
#   - Processa imagens e vídeos para realizar tarefas como reconhecimento facial, detecção de objetos, etc.
#   - Exemplo: Sistemas de segurança com câmeras inteligentes.
#
# - **IA em Robótica:**
#   - Combina IA com sistemas físicos para realizar tarefas como manipulação de objetos ou navegação autônoma.
#   - Exemplo: Robôs industriais e veículos autônomos.
#
# - **IA em Jogos:**
#   - Desenvolvida para jogar jogos de estratégia ou simulação.
#   - Exemplo: AlphaGo, que joga Go em nível de mestre.
#
# ---
#
# ### **Resumo**
# A IA pode ser categorizada de várias formas, dependendo do foco: tarefas específicas, capacidade de aprendizado, autonomia ou até mesmo especulações sobre o futuro. Atualmente, a maioria das aplicações de IA são de **IA fraca**, projetadas para tarefas específicas, mas pesquisadores continuam explorando formas de alcançar níveis mais avançados de inteligência artificial.
# --------------
#
# ::::: Modelo 2: anthropic:claude-3-5-sonnet-20241022 :::::
# Existem principalmente três tipos de Inteligência Artificial (IA):
#
# 1. IA Fraca (ou Estreita):
# - É a mais comum atualmente
# - Especializada em tarefas específicas
# - Exemplos: assistentes virtuais, sistemas de recomendação, reconhecimento facial
#
# 2. IA Forte (ou Geral):
# - Seria capaz de realizar qualquer tarefa intelectual humana
# - Ainda não existe na prática
# - Teria consciência e compreensão real
# - É um objetivo teórico da área
#
# 3. IA Superinteligente:
# - Superaria a inteligência humana em todos os aspectos
# - É um conceito teórico/futurista
# - Alvo de debates éticos e filosóficos
#
# Outras classificações incluem:
#
# Por Funcionamento:
# - Baseada em Regras
# - Machine Learning
# - Deep Learning
# - Redes Neurais
#
# Por Capacidade:
# - Reativa
# - Memória Limitada
# - Teoria da Mente
# - Autoconsciente
#
# Por Aplicação:
# - IA Analítica
# - IA Funcional
# - IA Interativa
# - IA Textual
# - IA Visual
# --------------
#
# ::::: Modelo 3: groq:llama-3.3-70b-versatile :::::
# Existem vários tipos de inteligência artificial, cada um com suas próprias características e aplicações. Aqui estão alguns dos principais tipos de inteligência artificial:
#
# 1. **Inteligência Artificial Fraca**: É o tipo mais comum de inteligência artificial e é projetada para realizar tarefas específicas, como jogos, reconhecimento de imagem e voz, etc. Ela não tem consciência ou autoconsciência.
# 2. **Inteligência Artificial Forte**: É um tipo de inteligência artificial que visa criar máquinas que possam pensar e aprender como os seres humanos. Ela é capaz de realizar tarefas mais complexas, como resolução de problemas e tomada de decisões.
# 3. **Inteligência Artificial Superinteligente**: É um tipo de inteligência artificial que é significativamente mais avançada do que a inteligência humana. Ela pode ser capaz de resolver problemas complexos de forma mais eficiente do que os humanos.
# 4. **Aprendizado de Máquina**: É um tipo de inteligência artificial que permite que as máquinas aprendam com os dados e melhorem seu desempenho ao longo do tempo. Ele é usado em aplicações como reconhecimento de imagem, voz e texto.
# 5. **Redes Neurais**: São modelos de inteligência artificial inspirados no funcionamento do cérebro humano. Elas são compostas por camadas de neurônios artificiais que processam e transmitem informações.
# 6. **Inteligência Artificial Simbólica**: É um tipo de inteligência artificial que usa símbolos e regras para representar e manipular conhecimento. Ela é usada em aplicações como sistemas de diagnóstico médico e sistemas de planejamento.
# 7. **Inteligência Artificial de Nuvem**: É um tipo de inteligência artificial que é executada na nuvem, permitindo que as máquinas aprendam e sejam treinadas em grandes conjuntos de dados.
# 8. **Inteligência Artificial de Borda**: É um tipo de inteligência artificial que é executada em dispositivos de borda, como smartphones e sensores, permitindo que as máquinas aprendam e sejam treinadas em tempo real.
#
# Além disso, existem também subtipos de inteligência artificial, como:
#
# * **Visão Computacional**: É um campo da inteligência artificial que se concentra em permitir que as máquinas vejam e interpretem o mundo visual.
# * **Processamento de Linguagem Natural**: É um campo da inteligência artificial que se concentra em permitir que as máquinas entendam e gerem linguagem humana.
# * **Robótica**: É um campo da inteligência artificial que se concentra em permitir que as máquinas interajam com o mundo físico.
#
# Esses são apenas alguns exemplos dos muitos tipos de inteligência artificial que existem. A inteligência artificial é um campo em constante evolução, e novas aplicações e subtipos estão sendo desenvolvidos regularmente.
# --------------
#
#
# ##### Pergunta 4: Como o cérebro realmente aprende? #####
#
# ::::: Modelo 1: groq:deepseek-r1-distill-llama-70b :::::
# O cérebro aprende através de um processo complexo que envolve vários mecanismos neurobiológicos e psicológicos. Aqui está uma visão geral simplificada de como o cérebro aprende:
#
# 1. **Neuroplasticidade**: O cérebro tem a capacidade de se adaptar e mudar ao longo da vida. Essa capacidade, chamada de neuroplasticidade, permite que novas conexões sejam formadas entre os neurônios (sinapses) e que as existentes sejam fortalecidas ou enfraquecidas com base na experiência.
#
# 2. **Consolidação da Memória**: Quando aprendemos algo novo, a informação é primeiro armazenada na memória de curto prazo. Com o tempo e a repetição, essa informação é transferida para a memória de longo prazo. Esse processo é chamado de consolidação e pode ocorrer durante o sono.
#
# 3. **Aprendizado Associativo**: O cérebro aprende associando estímulos, comportamentos e resultados. Por exemplo, o condicionamento clássico (como o experimento de Pavlov com os cães) e o condicionamento operante (como a teoria de Skinner) são exemplos de como o cérebro associa ações e consequências.
#
# 4. **Repetição e Prática**: A repetição de uma tarefa ou informação ajuda a fortalecer as conexões neurais. Quanto mais vezes uma informação é processada, mais sólida se torna na memória.
#
# 5. **Contexto Emocional**: As emoções desempenham um papel importante no aprendizado. Experiências emocionais tendem a ser lembradas com mais clareza do que experiências neutras, pois o cérebro libera hormônios como a adrenalina e o cortisol durante situações emocionais, reforçando a memória.
#
# 6. **Motivação e Interesse**: A motivação e o interesse aumentam a capacidade de aprendizado. Quando estamos interessados em algo, nosso cérebro está mais ativo e receptivo para absorver nova informação.
#
# 7. **Sono e Descanso**: O sono é crucial para o aprendizado. Durante o sono, o cérebro processa e consolida as memórias, ajudando a transferir informações da memória de curto prazo para a de longo prazo.
#
# 8. **Prática Ativa**: A prática ativa, como resolver problemas ou ensinar o que aprendemos para outros, ajuda a reforçar o aprendizado. A prática passiva, como ler ou ouvir, é menos eficaz do que a prática ativa.
#
# Resumindo, o cérebro aprende através da formação e fortalecimento de conexões neurais, influenciado por fatores como repetição, emoção, motivação, sono e prática.
# --------------
#
# ::::: Modelo 2: anthropic:claude-3-5-sonnet-20241022 :::::
# O processo de aprendizagem no cérebro é complexo e envolve vários mecanismos. Aqui estão os principais aspectos:
#
# 1. Plasticidade Neuronal
# - O cérebro modifica suas conexões neuronais (sinapses)
# - Novas conexões são formadas e outras são fortalecidas
# - Conexões pouco usadas podem ser eliminadas
#
# 2. Potenciação de Longo Prazo (LTP)
# - Fortalecimento das sinapses através de uso repetido
# - Quanto mais uma conexão é usada, mais forte ela se torna
# - Base neurobiológica da memória
#
# 3. Neurotransmissores
# - Substâncias químicas que facilitam a comunicação entre neurônios
# - Dopamina: importante para motivação e recompensa
# - Acetilcolina: crucial para atenção e memória
#
# 4. Consolidação da Memória
# - Transferência de informações da memória de curto para longo prazo
# - Ocorre principalmente durante o sono
# - Envolve repetição e associação com conhecimentos prévios
#
# 5. Fatores que influenciam o aprendizado:
# - Atenção e foco
# - Emoções
# - Motivação
# - Sono adequado
# - Alimentação
# - Exercício físico
#
# 6. Múltiplos sistemas de memória
# - Memória declarativa (fatos e eventos)
# - Memória procedural (habilidades e hábitos)
# - Memória de trabalho (processamento temporário)
# --------------
#
# ::::: Modelo 3: groq:llama-3.3-70b-versatile :::::
# **Aprendizado no Cérebro: Um Processo Complexo**
#
# O cérebro humano é um órgão incrivelmente complexo e complexo, e o processo de aprendizado é um dos mais fascinantes e importantes. O aprendizado é um processo que ocorre ao longo da vida, desde o nascimento até a idade adulta, e é fundamental para o nosso desenvolvimento e adaptação ao mundo ao nosso redor.
#
# **O Que é Aprendizado?**
#
# Aprendizado é o processo pelo qual o cérebro procesa e armazena informações, habilidades e conhecimentos novos. Isso pode ser feito através de experiências, prática, observação, leitura, ouvindo e conversando com outras pessoas.
#
# **Como o Cérebro Aprende?**
#
# O cérebro aprende através de um processo que envolve várias etapas:
#
# 1. **Percepção**: O cérebro recebe informações através dos sentidos (visão, audição, tato, paladar e olfato).
# 2. **Processamento**: As informações são processadas pelo córtex cerebral, onde são analisadas e interpretadas.
# 3. **Consolidação**: As informações processadas são armazenadas na memória de curto prazo, que é uma área do cérebro que armazena informações por um período curto.
# 4. **Repetição**: A repetição é fundamental para o aprendizado. Quanto mais vezes o cérebro repete uma informação, mais forte se torna a conexão entre as células nervosas (neurônios).
# 5. **Consolidação de longo prazo**: Com o tempo, as informações armazenadas na memória de curto prazo são transferidas para a memória de longo prazo, que é uma área do cérebro que armazena informações por um período mais longo.
#
# **Neurônios e Sinapses**
#
# Os neurônios são as células nervosas que compõem o cérebro. Eles são responsáveis por processar e transmitir informações. As sinapses são as conexões entre os neurônios, onde as informações são transmitidas de um neurônio para outro.
#
# Quando o cérebro aprende algo novo, as sinapses entre os neurônios se fortalecem, permitindo que as informações sejam transmitidas mais rapidamente e com mais eficiência. Isso é conhecido como **potenciação sináptica**.
#
# **Fatores que Influenciam o Aprendizado**
#
# Existem vários fatores que influenciam o aprendizado, incluindo:
#
# * **Atenção**: A capacidade de se concentrar e prestar atenção às informações.
# * **Motivação**: A motivação para aprender é fundamental para o sucesso.
# * **Prática**: A prática é essencial para consolidar as informações e habilidades.
# * **Descanso**: O descanso é importante para permitir que o cérebro processe e consolide as informações.
#
# **Conclusão**
#
# O aprendizado é um processo complexo que envolve várias etapas, desde a percepção até a consolidação de longo prazo. O cérebro aprende através da repetição, prática e motivação, e os neurônios e sinapses desempenham um papel fundamental nesse processo. Entender como o cérebro aprende pode ajudar a melhorar a capacidade de aprender e a otimizar o processo de aprendizado.
# --------------
#
#
# ##### Pergunta 5: Porque Oeiras deixou de ser a capital do Piauí? #####
#
# ::::: Modelo 1: groq:deepseek-r1-distill-llama-70b :::::
# Oeiras deixou de ser a capital do Piauí e foi substituída por Teresina devido a vários fatores estratégicos e de desenvolvimento.
#
# 1. **Localização Geográfica**: Teresina está situada à beira do rio Parnaíba, o que facilitava o transporte fluvial e o comércio, tornando-a um ponto mais central e acessível para a população do estado.
#
# 2. **Desenvolvimento Econômico**: Teresina experimentou um crescimento econômico significativo, impulsionado por sua posição estratégica e recursos naturais, tornando-se um centro econômico mais vibrante em comparação a Oeiras.
#
# 3. **Infraestrutura**: A nova capital oferecia melhor infraestrutura, incluindo vias de transporte e comunicação, essenciais para o funcionamento administrativo do estado.
#
# 4. **Reforma Administrativa**: A mudança ocorreu durante um período de reformas administrativas no século XIX, visando modernizar a gestão do estado e melhorar a acessibilidade para a população.
#
# Esses fatores combinados levaram à decisão de transferir a capital para Teresina, tornando-a mais adequada para atender às necessidades do Piauí.
# --------------
#
# ::::: Modelo 2: anthropic:claude-3-5-sonnet-20241022 :::::
# Oeiras deixou de ser a capital do Piauí em 1852 devido a vários fatores:
#
# 1. Localização geográfica desfavorável: Oeiras ficava distante do litoral e tinha difícil acesso, o que dificultava o comércio e a comunicação com outras regiões.
#
# 2. Questões econômicas: A cidade de Teresina (nova capital) estava localizada às margens do Rio Parnaíba, principal via de transporte da época, o que facilitava o comércio e o desenvolvimento econômico.
#
# 3. Desenvolvimento regional: Teresina estava em uma posição estratégica entre o norte e o sul do estado, facilitando a administração e integração do território.
#
# 4. Decisão política: O presidente da província, José Antônio Saraiva, defendeu a mudança da capital para uma localização mais favorável ao desenvolvimento do estado.
#
# A transferência da capital para Teresina foi oficializada em 16 de agosto de 1852, tornando-se a primeira capital planejada do Brasil. A mudança visava modernizar a administração e promover o desenvolvimento econômico do Piauí, aproveitando melhor sua posição geográfica e recursos naturais.
# --------------
#
# ::::: Modelo 3: groq:llama-3.3-70b-versatile :::::
# Uma pergunta interessante sobre a história do Piauí!
#
# Oeiras foi a capital do Piauí de 1718 a 1811. No entanto, em 1811, a capital foi transferida para Teresina, que permanece sendo a capital do estado até hoje.
#
# A transferência da capital ocorreu devido a uma combinação de fatores. Aqui estão alguns dos principais motivos:
#
# 1. **Localização estratégica**: Teresina está localizada em uma posição mais central e estratégica no estado, próximo ao Rio Parnaíba, que é uma importante via de transporte e comércio. Já Oeiras está localizada no interior do estado, longe das principais rotas de comércio e comunicação.
# 2. **Acesso ao rio**: Teresina tem acesso direto ao Rio Parnaíba, o que facilitou a navegação e o comércio com outras regiões do Brasil e do exterior. Oeiras, por outro lado, não tem acesso direto a nenhum rio importante.
# 3. **Desenvolvimento econômico**: Teresina estava experimentando um crescimento econômico mais rápido do que Oeiras, devido à sua localização estratégica e ao acesso ao rio. A cidade estava se tornando um importante centro comercial e industrial do estado.
# 4. **Decisão política**: A transferência da capital também foi influenciada por decisões políticas. O governo provisório do Piauí, que havia sido estabelecido em 1811, decidiu transferir a capital para Teresina para fortalecer a economia e a administração do estado.
#
# Esses fatores contribuíram para a transferência da capital do Piauí de Oeiras para Teresina, que desde então tem sido a capital do estado.
# --------------
#
#
# 📝 Autoavaliação para a pergunta: O que é Engenharia de software aplicada?
#
# 🤖 Avaliação do modelo groq:deepseek-r1-distill-llama-70b:
# 📊 Resultado da avaliação:
# **Ranking:
#
# 1. **Terceira Resposta**:
#    - **Clareza e Coerência**: Excelente, com uma estrutura lógica e explicação detalhada.
#    - **Precisão da Informação**: Aborda objetivos, áreas de aplicação, técnicas e ferramentas de forma precisa.
#    - **Criatividade ou Profundidade**: Oferece exemplos práticos e explica a importância da manutenção de software.
#    - **Consistência Gramatical**: Sem erros, com linguagem fluida e natural.
#
# 2. **Primeira Resposta**:
#    - **Clareza e Coerência**: Muito clara, mas em inglês, o que pode ser uma desvantagem para o público de língua portuguesa.
#    - **Precisão da Informação**: Informações precisas e abrangentes, cobrindo desde o escopo até a aprendizagem contínua.
#    - **Criatividade ou Profundidade**: Estrutura bem organizada, mas em inglês.
#    - **Consistência Gramatical**: Sem erros, mas não aplicável ao português.
#
# 3. **Segunda Resposta**:
#    - **Clareza e Coerência**: Estrutura clara, mas um pouco concisa, podendo ser menos envolvente.
#    - **Precisão da Informação**: Precisa, cobrindo características, áreas, benefícios, práticas e ferramentas.
#    - **Criatividade ou Profundidade**: Falta profundidade nas explicações, mais focada em listas.
#    - **Consistência Gramatical**: Sem erros, mas estilo mais direto.
#
# **Melhor Resposta**: A terceira resposta é a melhor, pois equilibra estrutura, profundidade e clareza em português, tornando-a a mais eficaz para o público-alvo.
# ====================================================
#
# 🤖 Avaliação do modelo anthropic:claude-3-5-sonnet-20241022:
# 📊 Resultado da avaliação:
# Vou analisar cada resposta de acordo com os critérios solicitados:
#
# Resposta 1 (em inglês):
# - Clareza/Coerência: 8/10
# - Precisão: 9/10
# - Profundidade: 8/10
# - Gramática: 9/10
# Total: 34/40
#
# Resposta 2:
# - Clareza/Coerência: 8/10
# - Precisão: 8/10
# - Profundidade: 7/10
# - Gramática: 9/10
# Total: 32/40
#
# Resposta 3:
# - Clareza/Coerência: 9/10
# - Precisão: 9/10
# - Profundidade: 9/10
# - Gramática: 9/10
# Total: 36/40
#
# A melhor resposta é a número 3, pelos seguintes motivos:
# 1. Apresenta uma estrutura mais clara e organizada, com seções bem definidas
# 2. Oferece uma explicação mais completa e detalhada do tema
# 3. Inclui exemplos práticos e aplicações específicas
# 4. Mantém um equilíbrio entre informação técnica e explicação acessível
# 5. Conclui de forma apropriada, amarrando os conceitos apresentados
#
# Embora as outras respostas também sejam boas, a resposta 3 se destaca por:
# - Melhor estruturação do conteúdo
# - Maior profundidade na explicação dos conceitos
# - Exemplos mais concretos e aplicáveis
# - Linguagem mais adequada ao público brasileiro
# - Conclusão que sintetiza bem o conteúdo apresentado
# ====================================================
#
# 🤖 Avaliação do modelo groq:llama-3.3-70b-versatile:
# 📊 Resultado da avaliação:
# Avaliando as respostas com base nos critérios fornecidos, aqui está o ranqueamento:
#
# 1. **Resposta 1: Applied Software Engineering: A Comprehensive Overview**
#    - **Clareza e Coerência:** 9/10 (A resposta é bem estruturada e aborda vários aspectos da Engenharia de Software Aplicada de maneira clara.)
#    - **Precisão da Informação:** 9/10 (A informação fornecida é precisa e cobre uma ampla gama de tópicos relevantes.)
#    - **Criatividade ou Profundidade:** 8/10 (A resposta oferece uma visão geral abrangente, mas não apresenta ideias particularmente novas ou profundas.)
#    - **Consistência Gramatical:** 9/10 (O texto está bem escrito, com poucos ou nenhum erro gramatical.)
#
# 2. **Resposta 2: A Engenharia de Software Aplicada**
#    - **Clareza e Coerência:** 8/10 (A resposta é clara, mas um pouco mais concisa e menos detalhada do que a primeira.)
#    - **Precisão da Informação:** 8.5/10 (A informação é precisa, mas não tão detalhada quanto a primeira resposta.)
#    - **Criatividade ou Profundidade:** 7/10 (A abordagem é mais direta, sem muita profundidade ou novidade.)
#    - **Consistência Gramatical:** 9/10 (O texto está bem escrito, com boa estruturação e poucos erros.)
#
# 3. **Resposta 3: Introdução à Engenharia de Software Aplicada**
#    - **Clareza e Coerência:** 8.5/10 (A resposta oferece uma boa introdução, mas pode ser um pouco mais detalhada em alguns aspectos.)
#    - **Precisão da Informação:** 8.5/10 (A informação é precisa, mas a resposta não oferece tantos detalhes quanto a primeira.)
#    - **Criatividade ou Profundidade:** 7.5/10 (A abordagem é mais didática, sem muita inovação.)
#    - **Consistência Gramatical:** 9/10 (O texto está bem escrito, com estruturação lógica e poucos erros.)
#
# **Melhor Resposta:**
# Com base na avaliação, a **Resposta 1: Applied Software Engineering: A Comprehensive Overview** é a melhor. Ela oferece uma visão geral abrangente e detalhada da Engenharia de Software Aplicada, abordando vários aspectos importantes com clareza e coerência. Além disso, a resposta demonstra uma boa combinação de precisão da informação, criatividade na apresentação e consistência gramatical, o que a torna a mais completa e útil entre as opções apresentadas.
# ====================================================
#
# 📝 Autoavaliação para a pergunta: O que é uma função em programação?
#
# 🤖 Avaliação do modelo groq:deepseek-r1-distill-llama-70b:
# 📊 Resultado da avaliação:
# **Ranking:**
#
# 1. **Response 1**
#    - **Clarity and Coherence:** Excellent. The response is well-structured and easy to follow.
#    - **Precision:** Accurate and covers all necessary aspects.
#    - **Creativity/Depth:** Provides a good balance of depth without being too verbose.
#    - **Grammatical Consistency:** No errors, clear and precise language.
#
# 2. **Response 3**
#    - **Clarity and Coherence:** Good, though slightly more complex structure.
#    - **Precision:** Detailed and accurate.
#    - **Creativity/Depth:** Offers a conclusion and detailed structure.
#    - **Grammatical Consistency:** Well-written, precise language.
#
# 3. **Response 2**
#    - **Clarity and Coherence:** Clear and concise.
#    - **Precision:** Accurate but less detailed.
#    - **Creativity/Depth:** Uses a helpful analogy.
#    - **Grammatical Consistency:** No errors, clear language.
#
# **Best Response:** Response 1, as it offers the best balance of clarity, precision, and depth without unnecessary complexity.
# ====================================================
#
# 🤖 Avaliação do modelo anthropic:claude-3-5-sonnet-20241022:
# 📊 Resultado da avaliação:
# Vou analisar cada resposta de acordo com os critérios solicitados:
#
# Resposta 1:
# - Clareza e Coerência: 9/10 (Muito bem estruturada e organizada)
# - Precisão da Informação: 9/10 (Informações precisas e bem detalhadas)
# - Criatividade/Profundidade: 8/10 (Boa profundidade com exemplo prático)
# - Consistência Gramatical: 9/10 (Excelente redação)
# Total: 35/40
#
# Resposta 2:
# - Clareza e Coerência: 8/10 (Clara, mas menos estruturada)
# - Precisão da Informação: 8/10 (Informações corretas, mas menos detalhadas)
# - Criatividade/Profundidade: 9/10 (Analogia criativa com receita de bolo)
# - Consistência Gramatical: 8/10 (Boa redação)
# Total: 33/40
#
# Resposta 3:
# - Clareza e Coerência: 8/10 (Bem estruturada)
# - Precisão da Informação: 8/10 (Informações precisas)
# - Criatividade/Profundidade: 7/10 (Menos criativa, mas informativa)
# - Consistência Gramatical: 8/10 (Boa redação)
# Total: 31/40
#
# A melhor resposta é a Resposta 1 porque:
# 1. Possui uma estrutura mais clara e organizada com tópicos bem definidos
# 2. Apresenta informações mais completas e detalhadas
# 3. Inclui tanto aspectos teóricos quanto práticos
# 4. Usa formatação adequada para facilitar a leitura
# 5. Oferece um exemplo prático bem explicado
# 6. Aborda todos os aspectos importantes de funções de forma equilibrada
#
# A resposta 1 consegue combinar profundidade técnica com clareza na explicação, tornando o conceito acessível tanto para iniciantes quanto para programadores mais experientes. O uso de marcadores e seções bem definidas também ajuda na compreensão progressiva do conceito.
# ====================================================
#
# 🤖 Avaliação do modelo groq:llama-3.3-70b-versatile:
# 📊 Resultado da avaliação:
# Avaliação das Respostas:
#
# 1. **Clareza e Coerência**:
#    - Resposta 1: Excelente. A resposta é clara, concisa e bem estruturada, começando com uma definição clara, seguida por características principais, vantagens e um exemplo prático.
#    - Resposta 2: Boa. A resposta é clara e direta, mas menos detalhada em comparação com a primeira resposta. Ela aborda os pontos principais, mas de forma mais simplificada.
#    - Resposta 3: Excelente. Esta resposta é detalhada, bem estruturada e oferece uma introdução, características, estrutura de uma função e um exemplo, mantendo a clareza ao longo do texto.
#
# 2. **Precisão da Informação**:
#    - Resposta 1: Precisa. A informação fornecida é precisa e abrange todos os aspectos importantes de uma função em programação.
#    - Resposta 2: Precisa, mas simplificada. A resposta fornece informações precisas, mas de forma mais superficial em comparação com as outras respostas.
#    - Resposta 3: Precisa. A resposta oferece uma explicação detalhada e precisa sobre funções, incluindo características, estrutura e exemplos.
#
# 3. **Criatividade ou Profundidade**:
#    - Resposta 1: Boa. A resposta oferece uma explicação detalhada e inclui um exemplo prático, demonstrando criatividade na forma como a informação é apresentada.
#    - Resposta 2: Regular. A resposta é mais direta e menos criativa em termos de explicação e exemplo.
#    - Resposta 3: Excelente. Esta resposta demonstra uma grande profundidade na explicação, abordando vários aspectos das funções, incluindo reutilização de código, modularidade e abstração, além de um exemplo ilustrativo.
#
# 4. **Consistência Gramatical**:
#    - Resposta 1: Excelente. A gramática e a pontuação são corretas e consistentes ao longo da resposta.
#    - Resposta 2: Boa. A resposta apresenta poucos erros gramaticais e é compreensível, mas menos polida do que as outras.
#    - Resposta 3: Excelente. A resposta é bem escrita, com boa gramática eWithout erros notáveis.
#
# **Melhor Resposta:** A melhor resposta é a **Resposta 1**. Ela combina clareza, precisão, criatividade e consistência gramatical de maneira exemplar, oferecendo uma explicação abrangente e fácil de entender sobre o que são funções em programação, seus benefícios e como elas são estruturadas, além de um exemplo prático ilustrativo em Python.
# ====================================================
#
# 📝 Autoavaliação para a pergunta: Quais os tipos de inteligência artificial?
#
# 🤖 Avaliação do modelo groq:deepseek-r1-distill-llama-70b:
# 📊 Resultado da avaliação:
# **Resposta Rankizada:**
#
# 1. **Resposta 1**:
#    - **Clareza e Coerência**: Excelente estruturação com categorias claras e lógicas.
#    - **Precisão da Informação**: Precisa e abrangente, cobrindo desde IA Fraca até conceitos teóricos.
#    - **Criatividade ou Profundidade**: Oferece uma abordagem criativa ao categorizar a IA de múltiplas formas.
#    - **Consistência Gramatical**: Sem erros, com linguagem clara e resumo final eficaz.
#
# 2. **Resposta 2**:
#    - **Clareza e Coerência**: Simples e fácil de seguir, mas menos detalhada.
#    - **Precisão da Informação**: Correta, mas falta profundidade.
#    - **Criatividade ou Profundidade**: Menos criativa, com uma abordagem mais básica.
#    - **Consistência Gramatical**: Boa, mas menos informativa.
#
# 3. **Resposta 3**:
#    - **Clareza e Coerência**: Menos clara devido ao excesso de informações e estrutura desorganizada.
#    - **Precisão da Informação**: Algumas imprecisões e classificações questionáveis.
#    - **Criatividade ou Profundidade**: Tentativa de abrangência, mas falta organização.
#    - **Consistência Gramatical**: Algumas inconsistências menores.
#
# **Conclusão**: A **Resposta 1** é a melhor, pois oferece uma visão clara, precisa e bem estruturada dos tipos de inteligência artificial, tornando-a a mais compreensível e informativa.
# ====================================================
#
# 🤖 Avaliação do modelo anthropic:claude-3-5-sonnet-20241022:
# 📊 Resultado da avaliação:
# Vou analisar cada resposta de acordo com os critérios solicitados:
#
# Resposta 1:
# - Clareza e Coerência: 10/10 (Muito bem estruturada e organizada)
# - Precisão da Informação: 9/10 (Informações detalhadas e precisas)
# - Criatividade/Profundidade: 9/10 (Abordagem abrangente e bem detalhada)
# - Consistência Gramatical: 9/10 (Texto bem escrito e consistente)
# Total: 37/40
#
# Resposta 2:
# - Clareza e Coerência: 8/10 (Boa estrutura, mas mais simples)
# - Precisão da Informação: 7/10 (Informações básicas corretas)
# - Criatividade/Profundidade: 6/10 (Abordagem mais superficial)
# - Consistência Gramatical: 8/10 (Bem escrito)
# Total: 29/40
#
# Resposta 3:
# - Clareza e Coerência: 7/10 (Estrutura menos organizada)
# - Precisão da Informação: 8/10 (Informações precisas)
# - Criatividade/Profundidade: 7/10 (Boa profundidade, mas menos organizada)
# - Consistência Gramatical: 8/10 (Bem escrito)
# Total: 30/40
#
# A melhor resposta é a Resposta 1 porque:
# 1. Apresenta uma estrutura clara e bem organizada com categorias bem definidas
# 2. Oferece explicações detalhadas com exemplos práticos
# 3. Aborda o tema de múltiplas perspectivas (baseado em inteligência, pensamento, autonomia, etc.)
# 4. Inclui um resumo útil no final
# 5. Usa formatação efetiva para melhor compreensão
# 6. Mantém consistência na apresentação das informações
# 7. Fornece exemplos concretos para cada categoria
# 8. Demonstra maior profundidade e abrangência na análise do tema
#
# As outras respostas também são boas, mas não atingem o mesmo nível de organização, detalhamento e clareza da primeira resposta.
# ====================================================
#
# 🤖 Avaliação do modelo groq:llama-3.3-70b-versatile:
# 📊 Resultado da avaliação:
# Aqui está a avaliação das respostas com base nos critérios solicitados:
#
# 1. **Resposta 1**:
#    - **Clareza e Coerência**: 9/10 - A resposta é bem estruturada e fácil de seguir, com categorias claras e exemplos ilustrativos.
#    - **Precisão da Informação**: 9,5/10 - A informação fornecida é precisa e abrangente, cobrindo diferentes aspectos da inteligência artificial.
#    - **Criatividade ou Profundidade**: 8,5/10 - A resposta oferece uma visão detalhada dos diferentes tipos de inteligência artificial, embora siga uma abordagem mais tradicional e didn't apresentar novas perspectivas inovadoras.
#    - **Consistência Gramatical**: 9,5/10 - A resposta está bem escrita, com pouquíssimos erros gramaticais.
#
# 2. **Resposta 2**:
#    - **Clareza e Coerência**: 7,5/10 - A resposta é mais direta e concisa, mas falta uma estruturação mais clara e detalhada.
#    - **Precisão da Informação**: 8/10 - A informação básica está correta, mas a resposta não oferece tanto detalhe quanto a primeira.
#    - **Criatividade ou Profundidade**: 7/10 - A resposta apresenta os conceitos básicos sem aprofundar muito ou apresentar novas ideias.
#    - **Consistência Gramatical**: 9/10 - A resposta está bem escrita, com alguns erros menores.
#
# 3. **Resposta 3**:
#    - **Clareza e Coerência**: 8/10 - A resposta é razoavelmente clara, mas alguns pontos poderiam ser melhor conectados.
#    - **Precisão da Informação**: 8,5/10 - A informação fornecida é geralmente precisa, mas há alguns termos e conceitos que poderiam ser esclarecidos melhor.
#    - **Criatividade ou Profundidade**: 8/10 - A resposta oferece uma visão geral bem abrangente dos tipos de inteligência artificial, mas não traz muita inovação.
#    - **Consistência Gramatical**: 9/10 - A resposta está bem escrita, com poucos erros gramaticais.
#
# **Melhor Resposta:**
# Com base na avaliação, a **Resposta 1** é a melhor. Ela oferece uma visão abrangente e detalhada dos diferentes tipos de inteligência artificial, apresentada de forma clara e coerente. A precisão da informação é alta, e embora a criatividade não seja o foco principal, a profundidade com que os conceitos são explorados é notável. Além disso, a consistência gramatical é excelente, o que torna a leitura agradável e compreensível.
# ====================================================
#
# 📝 Autoavaliação para a pergunta: Como o cérebro realmente aprende?
#
# 🤖 Avaliação do modelo groq:deepseek-r1-distill-llama-70b:
# 📊 Resultado da avaliação:
# **Ranking das Respostas:**
#
# 1. **Resposta 1:**
#    - **Critérios:** Excelente clareza, coerência, precisão e profundidade.
#    - **Motivo:** Oferece uma abordagem estruturada e acessível, abrangendo vários aspectos do aprendizado de forma clara e concisa.
#
# 2. **Resposta 2:**
#    - **Critérios:** Alta precisão técnica e profundidade, mas menos clareza devido à densidade.
#    - **Motivo:** Detalha mecanismos neurobiológicos, o que é valioso, mas pode ser menos acessível para iniciantes.
#
# 3. **Resposta 3:**
#    - **Critérios:** Coerente e precisa, mas menos estruturada.
#    - **Motivo:** Explica o processo de forma narrativa, o que pode ser menos claro para alguns leitores.
#
# **Melhor Resposta:** Resposta 1.
# **Justificativa:** A Resposta 1 é a mais clara, bem estruturada e acessível, abordando todos os critérios de forma eficaz.
# ====================================================
#
# 🤖 Avaliação do modelo anthropic:claude-3-5-sonnet-20241022:
# 📊 Resultado da avaliação:
# Vou analisar cada resposta de acordo com os critérios solicitados:
#
# Resposta 1:
# - Clareza e Coerência: 9/10 (Muito bem estruturada e fluida)
# - Precisão da Informação: 9/10 (Informações precisas e bem fundamentadas)
# - Criatividade/Profundidade: 8/10 (Abordagem abrangente com exemplos práticos)
# - Consistência Gramatical: 9/10 (Excelente construção textual)
# Total: 35/40
#
# Resposta 2:
# - Clareza e Coerência: 8/10 (Estrutura em tópicos clara, mas menos fluida)
# - Precisão da Informação: 8/10 (Informações técnicas precisas)
# - Criatividade/Profundidade: 7/10 (Mais técnica, menos contextualizada)
# - Consistência Gramatical: 8/10 (Boa construção, mas mais esquemática)
# Total: 31/40
#
# Resposta 3:
# - Clareza e Coerência: 7/10 (Algumas redundâncias e organização menos eficiente)
# - Precisão da Informação: 7/10 (Informações mais básicas e generalistas)
# - Criatividade/Profundidade: 6/10 (Abordagem mais superficial)
# - Consistência Gramatical: 7/10 (Algumas repetições desnecessárias)
# Total: 27/40
#
# A melhor resposta é a Resposta 1 porque:
# 1. Apresenta uma estrutura mais coesa e fluida
# 2. Equilibra bem informações técnicas com explicações acessíveis
# 3. Oferece exemplos práticos e contextualizados
# 4. Mantém um nível consistente de profundidade
# 5. Aborda diversos aspectos do aprendizado de forma integrada
# 6. Possui excelente organização textual e progressão lógica
# 7. Inclui elementos práticos e teóricos de forma balanceada
#
# Esta resposta consegue ser simultaneamente informativa, acessível e bem estruturada, tornando-a a mais efetiva para explicar como o cérebro aprende.
# ====================================================
#
# 🤖 Avaliação do modelo groq:llama-3.3-70b-versatile:
# 📊 Resultado da avaliação:
# Com base nos critérios fornecidos, aqui está a minha avaliação das respostas:
#
# 1. **Clareza e Coerência**:
#    - Resposta 1: 9/10 (Muito clara e coerente, utilizando uma estrutura lógica e fácil de seguir.)
#    - Resposta 2: 8,5/10 (Clara, mas com alguns pontos que poderiam ser mais detalhados ou melhor conectados.)
#    - Resposta 3: 9/10 (Bastante clara e coerente, com uma boa estrutura que facilita a compreensão.)
#
# 2. **Precisão da Informação**:
#    - Resposta 1: 9,5/10 (Fornece uma visão geral ampla e precisa sobre como o cérebro aprende, abordando vários aspectos importantes.)
#    - Resposta 2: 9/10 (Precisa, mas não explora alguns tópicos com a mesma profundidade que a Resposta 1.)
#    - Resposta 3: 8,5/10 (Precisa, mas falta um pouco de detalhe em alguns pontos, especialmente em comparação com a Resposta 1.)
#
# 3. **Criatividade ou Profundidade**:
#    - Resposta 1: 9/10 (Aborda vários aspectos do aprendizado cerebral, mostrando uma boa compreensão do tema e oferecendo uma visão geral completa.)
#    - Resposta 2: 8/10 (Fornece uma visão técnica, mas não alcança o mesmo nível de criatividade ou profundidade que a Resposta 1.)
#    - Resposta 3: 8/10 (Oferece uma boa visão geral, mas não apresenta tanta criatividade ou profundidade em sua abordagem.)
#
# 4. **Consistência Gramatical**:
#    - Resposta 1: 9,5/10 (Praticamente perfeita em termos de gramática e ortografia.)
#    - Resposta 2: 9/10 (Muito boa, com apenas pequenos erros irrelevantes.)
#    - Resposta 3: 9/10 (Também muito boa, com uma escrita clara e correta.)
#
# **Ranking**:
# 1. **Resposta 1**: Com uma média de 9,4/10, esta resposta destaca-se por sua clareza, coerência, precisão da informação e consistência gramatical.
# 2. **Resposta 3**: Com uma média de 8,9/10, oferece uma boa combinação de clareza, precisão e criatividade, mas falta um pouco de detalhe em alguns pontos.
# 3. **Resposta 2**: Com uma média de 8,7/10, é precisa e clara, mas não alcança o mesmo nível de profundidade ou criatividade que as outras duas respostas.
#
# **Melhor Resposta**: A **Resposta 1** é a melhor, devido à sua abordagem completa, clara e precisa sobre como o cérebro aprende, além de sua apresentação muito bem estruturada e escrita.
# ====================================================
#
# 📝 Autoavaliação para a pergunta: Porque Oeiras deixou de ser a capital do Piauí?
#
# 🤖 Avaliação do modelo groq:deepseek-r1-distill-llama-70b:
# 📊 Resultado da avaliação:
# **Resposta Ranqueada:**
#
# 1. **Resposta 2**
#    - **Clareza e Coerência:** Excelente, bem estruturada.
#    - **Precisão da Informação:** Inclui o ano correto (1852) e detalhes como o presidente da província.
#    - **Criatividade ou Profundidade:** Destaca-se por incluir informações adicionais, como o nome do presidente.
#    - **Consistência Gramatical:** Sem erros.
#
# 2. **Resposta 1**
#    - **Clareza e Coerência:** Boa, mas menos detalhada.
#    - **Precisão da Informação:** Correta, mas sem o ano exato.
#    - **Criatividade ou Profundidade:** Genérica.
#    - **Consistência Gramatical:** Sem erros.
#
# 3. **Resposta 3**
#    - **Clareza e Coerência:** Afetada por um erro factual.
#    - **Precisão da Informação:** Erro na data da transferência.
#    - **Criatividade ou Profundidade:** Genérica.
#    - **Consistência Gramatical:** Sem erros, mas erro factual.
#
# **Melhor Resposta:** Resposta 2, por ser a mais detalhada e precisa.
# ====================================================
#
# 🤖 Avaliação do modelo anthropic:claude-3-5-sonnet-20241022:
# 📊 Resultado da avaliação:
# Vou analisar cada resposta de acordo com os critérios solicitados:
#
# Resposta 1:
# - Clareza e Coerência: 8/10 (bem estruturada e clara)
# - Precisão da Informação: 7/10 (informações gerais corretas, mas sem data específica)
# - Criatividade/Profundidade: 7/10 (boa explicação dos fatores)
# - Consistência Gramatical: 9/10 (muito bem escrita)
#
# Resposta 2:
# - Clareza e Coerência: 9/10 (muito bem estruturada e clara)
# - Precisão da Informação: 9/10 (inclui data precisa e detalhes históricos)
# - Criatividade/Profundidade: 8/10 (menciona fatos específicos como José Antônio Saraiva)
# - Consistência Gramatical: 9/10 (muito bem escrita)
#
# Resposta 3:
# - Clareza e Coerência: 7/10 (boa estrutura mas tem erro histórico)
# - Precisão da Informação: 4/10 (erro grave na data - 1811 ao invés de 1852)
# - Criatividade/Profundidade: 6/10 (explicação razoável mas com imprecisões)
# - Consistência Gramatical: 8/10 (bem escrita)
#
# A melhor resposta é a número 2 porque:
# 1. Fornece a data precisa da mudança (1852)
# 2. Menciona especificamente o presidente da província responsável
# 3. Inclui o fato interessante de Teresina ser a primeira capital planejada do Brasil
# 4. Apresenta uma estrutura clara e bem organizada
# 5. Tem precisão histórica e detalhamento adequado
# 6. Mantém um equilíbrio entre informação técnica e explicação acessível
#
# Esta resposta se destaca por combinar precisão histórica com boa organização e clareza na apresentação das informações.
# ====================================================
#
# 🤖 Avaliação do modelo groq:llama-3.3-70b-versatile:
# 📊 Resultado da avaliação:
# Aqui está o ranqueamento das respostas com base nos critérios solicitados:
#
# **Resposta 1:**
# - Clareza e Coerência: 8/10 (a resposta é clara, mas some pontos específicos sobre a chronologia e contexto histórico).
# - Precisão da Informação: 8/10 (a resposta fornece informações precisas, mas não especifica a data exata da transferência da capital).
# - Criatividade ou Profundidade: 6/10 (a resposta apresenta os principais motivos, mas não oferece uma análise mais profunda ou perspectivas inovadoras).
# - Consistência Gramatical: 9/10 (a resposta está bem escrita e é fácil de entender).
#
# **Resposta 2:**
# - Clareza e Coerência: 9/10 (a resposta é clara e coerente, apresentando os motivos de forma lógica).
# - Precisão da Informação: 9/10 (a resposta fornece informações precisas, incluindo a data específica da transferência da capital).
# - Criatividade ou Profundidade: 7/10 (a resposta oferece uma análise mais detalhada dos motivos, mas não apresenta perspectivas significativamente inovadoras).
# - Consistência Gramatical: 9/10 (a resposta está muito bem escrita e é fácil de entender).
#
# **Resposta 3:**
# - Clareza e Coerência: 7/10 (a resposta é clara, mas apresenta algumas inconsistências nos dados históricos).
# - Precisão da Informação: 6/10 (a resposta contém erros factuais, como a data da transferência da capital).
# - Criatividade ou Profundidade: 5/10 (a resposta não oferece uma análise profunda ou perspectivas inovadoras).
# - Consistência Gramatical: 8/10 (a resposta está bem escrita, mas com alguns erros menores).
#
# **Melhor Resposta:**
# Com base nos critérios, a **Resposta 2** é a melhor. Ela oferece uma combinação de clareza, precisão da informação, e consistência gramatical, apresentando os motivos da transferência da capital de Oeiras para Teresina de maneira lógica e coerente. Além disso, inclui detalhes importantes como a data específica da transferência, o que demonstra uma maior precisão na informação.
# ====================================================
